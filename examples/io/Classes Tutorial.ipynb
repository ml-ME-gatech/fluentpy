# %% [markdown]
# # IO Classes
# This notebook shows basic use cases for the io classes. Most classes inherit from base FluentFile, and all make use of pythons context managment- this means that the "with PythonObject as instance:" syntax is required to read files. For more on context managment:
#
# https://www.geeksforgeeks.org/context-manager-in-python/

# %% [markdown]
# ### ReportFileOut
# the report file out is intended to read files created by "report variables" in Fluent. These typically have a '.out' extension and the default naming is report-file-0.out. The ReportFileOut, like many files has a "readdf" method which will read the contents of the file into a pandas DataFrame.

# %%
from fluentpy.io.classes import ReportFileOut
import os
data_folder = 'data_files'

with ReportFileOut(os.path.join(data_folder,'report-file-0.out')) as rfile:
    df = rfile.readdf()

print(df)
# Out:
#                  cs-htc     cs-temp     max-temp          p-in
# Iteration
# 1             -0.514973  521.666480   522.494202  9.770612e+06
# 2             -0.072330  573.833122   574.603027  9.772086e+06
# 3             -0.032154  631.216434   632.006836  9.773973e+06
# 4             -0.057291  694.338079   695.151062  9.775655e+06
# 5             -0.071804  763.771889   764.609741  9.776419e+06
# ...                 ...         ...          ...           ...
# 817        13273.865069  837.622352  1202.924316  9.782954e+06
# 818        13273.882725  837.622031  1202.923828  9.782954e+06
# 819        13273.902107  837.621659  1202.923462  9.782954e+06
# 820        13273.918909  837.621313  1202.923096  9.782954e+06
# 821        13273.936812  837.620960  1202.922607  9.782954e+06
#
# [821 rows x 4 columns]

# %% [markdown]
# ### SolutionFile
#
# The solution file class handles reading solution files created in Fluent. Solution files are transcripts, essentially recordings of the convergence activity of the numerical solution. These files have ".trn" extension with a default naming of "Solution.trn"
#
# Solution files reading handles missing data by filling gaps with NaN. the size of the dataframe will be the total number of iterations, and any variable that begins later, or is reported at irregular intervals with be filled with NaN.

# %%
from fluentpy.io.classes import SolutionFile

#the first file here has no iterations, this will cause an AttributeError to be raised - left to the user to be handled
with SolutionFile(os.path.join(data_folder,'Solution.trn')) as sfile:
    df = sfile.readdf()
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# ~\OneDrive - Georgia Institute of Technology\Desktop\repository\fluentpy\io\classes.py in get_data(self)
#    1000         try:
# -> 1001             columns = re.split('\s+',solution_text[0:next(eol1).start()].strip())[0:-1]
#    1002         except StopIteration:
#
# ~\Anaconda3\lib\site-packages\more_itertools\more.py in __next__(self)
#     356
# --> 357         return next(self._it)
#     358
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-138a16852e65> in <module>
#       3 #the first file here has no iterations, this will cause an AttributeError to be raised - left to the user to be handled
#       4 with SolutionFile(os.path.join(data_folder,'Solution.trn')) as sfile:
# ----> 5     df = sfile.readdf()
#       6
#
# ~\OneDrive - Georgia Institute of Technology\Desktop\repository\fluentpy\io\classes.py in readdf(self)
#    1027         """
#    1028
# -> 1029         cleaned_text,columns = self.get_data()
#    1030         #hope that you can convert the text - deals with (or tries to) deal
#    1031         #with recorded data with inconsistent reporting width
#
# ~\OneDrive - Georgia Institute of Technology\Desktop\repository\fluentpy\io\classes.py in get_data(self)
#    1001             columns = re.split('\s+',solution_text[0:next(eol1).start()].strip())[0:-1]
#    1002         except StopIteration:
# -> 1003             raise AttributeError('no columns found in solution file')
#    1004
#    1005         while True:
#
# AttributeError: no columns found in solution file

# %%
with SolutionFile(os.path.join(data_folder,'Solution-2.trn')) as sfile:
    df = sfile.readdf()

# %% [markdown]
# ### PostDataFile
# The PostDataFile reads data outputted from CFD post. The PostDataFile class can be treated as above by reading a single dataframe, or as a dictionary, reading multiple data frames if there are multiple surfaces in the post file. the PostDataFile works with multiple variable export, and assigns the keys of the dictionaries based on the names of the surfaces. These files usually have a .csv extension.

# %%
from fluentpy.io.classes import PostDataFile

with PostDataFile(os.path.join(data_folder,'yplus_and_htc_data.csv')) as pdfile:
    pdfile.readdf()
    
for key in pdfile.keys(): 
    print('Surface: {}'.format(key))
    print('Columns')
    print(pdfile[key].columns)
    print('')
# Out:
# Surface: inner_tube inner_tube_inner_surface
# Columns
# Index(['X [ m ]', 'Y [ m ]', 'Z [ m ]',
#        'Surface Heat Transfer Coefficient [ W m^-2 K^-1 ]', 'Yplus'],
#       dtype='object')
#
# Surface: inner_tube inner_tube_jet_walls
# Columns
# Index(['X [ m ]', 'Y [ m ]', 'Z [ m ]',
#        'Surface Heat Transfer Coefficient [ W m^-2 K^-1 ]', 'Yplus'],
#       dtype='object')
#
# Surface: inner_tube inner_tube_outer_surface
# Columns
# Index(['X [ m ]', 'Y [ m ]', 'Z [ m ]',
#        'Surface Heat Transfer Coefficient [ W m^-2 K^-1 ]', 'Yplus'],
#       dtype='object')
#
# Surface: outer_tube_2 outer_tube_inner_face shadow
# Columns
# Index(['X [ m ]', 'Y [ m ]', 'Z [ m ]',
#        'Surface Heat Transfer Coefficient [ W m^-2 K^-1 ]', 'Yplus'],
#       dtype='object')

# %% [markdown]
# ### XYDataFile
# The XYDataFile is designed to work with files exported from the "XY Plots" in Fluent. This is fairly similar to the format of PostDataFile with the representation of multiple data in a dictionary type manner. This does not handle missing data.

# %%
from fluentpy.io.classes import XYDataFile

with XYDataFile(os.path.join(data_folder,'temp40HF.xy')) as xydfile:
    xydfile.readdf()
    
for key in xydfile.keys():
    print(key)
    print(xydfile[key])
# Out:
# z1-80
#           Static Temperature
# -0.00732              328.41
# z1-7.5
#           Static Temperature
# -0.00097             310.319
# z1-60
#           Static Temperature
# -0.00643             321.822
# z1-5
#           Static Temperature
# -0.00065             310.207
# z1-40
#           Static Temperature
# -0.00478             316.899
# z1-20
#           Static Temperature
# -0.00254              312.25
# z1-2.5
#           Static Temperature
# -0.00032             310.153
# z1-180
#      Static Temperature
# 0.0             361.652
# z1-17.5
#           Static Temperature
# -0.00223              311.75
# z1-160
#           Static Temperature
# -0.00254             356.664
# z1-15
#           Static Temperature
# -0.00192             311.307
# z1-140
#           Static Temperature
# -0.00478             349.738
# z1-120
#           Static Temperature
# -0.00643             341.116
# z1-12.5
#           Static Temperature
# -0.00161             310.903
# z1-100
#           Static Temperature
# -0.00732             334.961
# z1-10
#           Static Temperature
# -0.00129             310.561
# z1-0
#                Static Temperature
# -2.210960e-19             310.223
# z2-80
#           Static Temperature
# -0.00732             334.099
# z2-7.5
#           Static Temperature
# -0.00097             313.793
# z2-60
#           Static Temperature
# -0.00643             327.015
# z2-5
#           Static Temperature
# -0.00065             313.628
# z2-40
#           Static Temperature
# -0.00478             321.533
# z2-20
#           Static Temperature
# -0.00254             315.486
# z2-2.5
#           Static Temperature
# -0.00032             313.511
# z2-180
#      Static Temperature
# 0.0             367.548
# z2-17.5
#           Static Temperature
# -0.00223             315.485
# z2-160
#           Static Temperature
# -0.00254             362.901
# z2-15
#           Static Temperature
# -0.00192              314.97
# z2-140
#           Static Temperature
# -0.00478              356.48
# z2-120
#           Static Temperature
# -0.00643             347.516
# z2-12.5
#           Static Temperature
# -0.00161             314.497
# z2-100
#           Static Temperature
# -0.00732             340.935
# z2-10
#           Static Temperature
# -0.00129             314.092
# z2-0
#      Static Temperature
# 0.0             313.568
# z3-80
#           Static Temperature
# -0.00732             338.984
# z3-7.5
#           Static Temperature
# -0.00097             319.112
# z3-60
#           Static Temperature
# -0.00643              331.92
# z3-5
#           Static Temperature
# -0.00065             318.864
# z3-40
#           Static Temperature
# -0.00478             326.554
# z3-20
#           Static Temperature
# -0.00254             320.833
# z3-2.5
#            Static Temperature
# -0.000321             318.632
# z3-180
#      Static Temperature
# 0.0             372.276
# z3-17.5
#           Static Temperature
# -0.00223             320.883
# z3-160
#           Static Temperature
# -0.00254             367.854
# z3-15
#           Static Temperature
# -0.00192             320.375
# z3-140
#           Static Temperature
# -0.00478             361.981
# z3-120
#           Static Temperature
# -0.00643             353.239
# z3-12.5
#           Static Temperature
# -0.00161             319.892
# z3-100
#           Static Temperature
# -0.00732             346.086
# z3-10
#           Static Temperature
# -0.00129             319.462
# z3-0
#                Static Temperature
# -3.566750e-19             318.641
# z4-80
#           Static Temperature
# -0.00732             343.602
# z4-7.5
#           Static Temperature
# -0.00097             320.252
# z4-60
#           Static Temperature
# -0.00643             335.771
# z4-5
#           Static Temperature
# -0.00065              319.98
# z4-40
#           Static Temperature
# -0.00478             329.334
# z4-20
#           Static Temperature
# -0.00254             322.398
# z4-2.5
#           Static Temperature
# -0.00032             319.747
# z4-180
#      Static Temperature
# 0.0             376.545
# z4-17.5
#           Static Temperature
# -0.00223             322.403
# z4-160
#           Static Temperature
# -0.00254             372.257
# z4-15
#           Static Temperature
# -0.00192             321.774
# z4-140
#           Static Temperature
# -0.00478             366.763
# z4-120
#           Static Temperature
# -0.00643             358.544
# z4-12.5
#           Static Temperature
# -0.00161             321.185
# z4-100
#           Static Temperature
# -0.00732             351.429
# z4-10
#           Static Temperature
# -0.00129             320.662
# z4-0
#                Static Temperature
# -2.526680e-19             319.767
# z5-80
#           Static Temperature
# -0.00732             348.243
# z5-7.5
#           Static Temperature
# -0.00097             323.237
# z5-60
#           Static Temperature
# -0.00643             339.978
# z5-5
#           Static Temperature
# -0.00065             322.911
# z5-40
#           Static Temperature
# -0.00478             333.049
# z5-20
#           Static Temperature
# -0.00254             325.586
# z5-2.5
#           Static Temperature
# -0.00032             322.615
# z5-180
#      Static Temperature
# 0.0             380.085
# z5-17.5
#           Static Temperature
# -0.00223             325.593
# z5-160
#           Static Temperature
# -0.00254             375.778
# z5-15
#           Static Temperature
# -0.00192              324.92
# z5-140
#           Static Temperature
# -0.00478             370.299
# z5-120
#           Static Temperature
# -0.00643             362.195
# z5-12.5
#           Static Temperature
# -0.00161             324.281
# z5-100
#           Static Temperature
# -0.00732             355.669
# z5-10
#           Static Temperature
# -0.00129             323.703
# z5-0
#      Static Temperature
# 0.0             322.608
# z6-80
#           Static Temperature
# -0.00732             349.849
# z6-7.5
#           Static Temperature
# -0.00097             325.906
# z6-60
#           Static Temperature
# -0.00643             342.755
# z6-5
#           Static Temperature
# -0.00065             325.532
# z6-40
#           Static Temperature
# -0.00478             336.299
# z6-20
#           Static Temperature
# -0.00254             328.443
# z6-2.5
#           Static Temperature
# -0.00032             325.182
# z6-180
#      Static Temperature
# 0.0             382.612
# z6-17.5
#           Static Temperature
# -0.00223             328.426
# z6-160
#           Static Temperature
# -0.00254             378.049
# z6-15
#           Static Temperature
# -0.00192             327.718
# z6-140
#           Static Temperature
# -0.00478             372.077
# z6-120
#           Static Temperature
# -0.00643             363.531
# z6-12.5
#           Static Temperature
# -0.00161             327.044
# z6-100
#           Static Temperature
# -0.00732             356.873
# z6-10
#           Static Temperature
# -0.00129              326.42
# z6-0
#      Static Temperature
# 0.0             325.157
# z7-80
#           Static Temperature
# -0.00732             350.195
# z7-7.5
#           Static Temperature
# -0.00097             326.219
# z7-60
#           Static Temperature
# -0.00643              342.49
# z7-5
#           Static Temperature
# -0.00065             325.864
# z7-40
#           Static Temperature
# -0.00478             336.042
# z7-20
#           Static Temperature
# -0.00254             328.627
# z7-2.5
#            Static Temperature
# -0.000322             325.425
# z7-180
#      Static Temperature
# 0.0             384.595
# z7-17.5
#           Static Temperature
# -0.00223             328.662
# z7-160
#           Static Temperature
# -0.00254             379.939
# z7-15
#           Static Temperature
# -0.00192             327.977
# z7-140
#           Static Temperature
# -0.00478             374.094
# z7-120
#           Static Temperature
# -0.00643             365.108
# z7-12.5
#           Static Temperature
# -0.00161             327.315
# z7-100
#           Static Temperature
# -0.00732             357.826
# z7-10
#           Static Temperature
# -0.00129             326.713
# z7-0
#                Static Temperature
# -1.626310e-19             325.504
# z8-80
#           Static Temperature
# -0.00732             364.312
# z8-7.5
#           Static Temperature
# -0.00097             327.843
# z8-60
#           Static Temperature
# -0.00643             350.718
# z8-5
#           Static Temperature
# -0.00065             327.408
# z8-40
#           Static Temperature
# -0.00478             340.546
# z8-20
#           Static Temperature
# -0.00254             330.942
# z8-2.5
#           Static Temperature
# -0.00032             327.016
# z8-180
#      Static Temperature
# 0.0             402.263
# z8-17.5
#           Static Temperature
# -0.00223             330.809
# z8-160
#           Static Temperature
# -0.00254             400.399
# z8-15
#           Static Temperature
# -0.00192             329.968
# z8-140
#           Static Temperature
# -0.00478             398.193
# z8-120
#           Static Temperature
# -0.00643              389.85
# z8-12.5
#           Static Temperature
# -0.00161             329.168
# z8-100
#           Static Temperature
# -0.00732             378.496
# z8-10
#           Static Temperature
# -0.00129             328.438
# z8-0
#      Static Temperature
# 0.0              326.98
# z9-80
#           Static Temperature
# -0.00732             411.046
# z9-7.5
#           Static Temperature
# -0.00097             335.479
# z9-60
#           Static Temperature
# -0.00643             384.802
# z9-5
#           Static Temperature
# -0.00065             334.788
# z9-40
#           Static Temperature
# -0.00478             359.747
# z9-20
#           Static Temperature
# -0.00254             341.107
# z9-2.5
#           Static Temperature
# -0.00032             334.212
# z9-180
#      Static Temperature
# 0.0             419.555
# z9-17.5
#           Static Temperature
# -0.00223             340.446
# z9-160
#           Static Temperature
# -0.00254             420.283
# z9-15
#           Static Temperature
# -0.00192              338.99
# z9-140
#           Static Temperature
# -0.00478             425.742
# z9-120
#           Static Temperature
# -0.00643             427.446
# z9-12.5
#           Static Temperature
# -0.00161              337.64
# z9-100
#           Static Temperature
# -0.00732              424.67
# z9-10
#           Static Temperature
# -0.00129              336.44
# z9-0
#      Static Temperature
# 0.0             334.138

# %% [markdown]
# ### SurfacePointFile
# the surface point file is meant for creating _and_ reading the results of surface points in Fluent. Points fall under the general category of "surfaces" in Fluent and are useful for extracting information from locations. The class only permits 3D data. The interface for creating input into fluent is through the classmethod "write_fluent_input_from_table" which takes arguments of
#
# X - the coordinates of the points, as a n x 3 size array
# file_name: the file name to write the file to, as a string
# export_variables: either a string or a list of strings of field variables we want to sample at the points
#
# The reading methods contain the standard readdf() method, which reads in the file. the method get_point_surface_data will read in the DataFrame, but will index the points based upon their position in the file

# %%
from fluentpy.io.classes import SurfacePointFile
import numpy as np

#creation of surface point file
X = np.linspace(0,1,10)[:,None]
X = np.concatenate([X,X,X],axis = 1)

#create input into Fluent
spf = SurfacePointFile.write_fluent_input_from_table(X,'surface_point_file','temperature')

# %%
#reading output of a surface point file
from fluentpy.io.classes import SurfacePointFile

with SurfacePointFile(os.path.join(data_folder,'point_input.psf.out')) as spf:
    df = spf.readdf()
    print(df)
    df = spf.get_point_surface_data()
    print(df)
# Out:
#             x-coordinate  y-coordinate  z-coordinate  temperature
# cellnumber
# 1          -1.307252e-06      0.007490        0.0656   345.220965
# 1          -2.561731e-03      0.007038        0.0656   363.257315
# 1          -4.814479e-03      0.005738        0.0656   399.911386
# 1          -6.486530e-03      0.003745        0.0656   442.032284
# 1          -7.376210e-03      0.001301        0.0656   477.983622
# ...                  ...           ...           ...          ...
# 1          -7.376211e-03     -0.001301        0.1744   329.300497
# 1          -6.486531e-03     -0.003745        0.1744   333.854659
# 1          -4.814479e-03     -0.005738        0.1744   339.532994
# 1          -2.561731e-03     -0.007038        0.1744   344.534674
# 1          -2.167941e-11     -0.007490        0.1744   348.375168
#
# [90 rows x 4 columns]
#     x-coordinate  y-coordinate  z-coordinate  temperature
# 0  -1.307252e-06      0.007490        0.0656   345.220965
# 1  -2.561731e-03      0.007038        0.0656   363.257315
# 2  -4.814479e-03      0.005738        0.0656   399.911386
# 3  -6.486530e-03      0.003745        0.0656   442.032284
# 4  -7.376210e-03      0.001301        0.0656   477.983622
# ..           ...           ...           ...          ...
# 85 -7.376211e-03     -0.001301        0.1744   329.300497
# 86 -6.486531e-03     -0.003745        0.1744   333.854659
# 87 -4.814479e-03     -0.005738        0.1744   339.532994
# 88 -2.561731e-03     -0.007038        0.1744   344.534674
# 89 -2.167941e-11     -0.007490        0.1744   348.375168
#
# [90 rows x 4 columns]

# %% [markdown]
# ### SphereSliceFile
#
# The SphereSliceFile is very similar to the SurfacePointFile, however it works with spheres rather than single points. Spheres consists of a list of datapoints rather than a single coordinates, and thus are slighlty more complicated to deal with. They also require specification of a radius in addition to their coordinates for input creation
#
# In addition to the standard "readdf()" method, this class also contains the method get_sphere_surface_data(operator) where operator must be a callable that operates on the data of the sphere, for example: np.mean,np.max,np.min,np.median. This returns the result

# %%
from fluentpy.io.classes import SphereSliceFile

#create input for fluent
R = np.ones_like(X.shape[0])*1e-2
ssf = SphereSliceFile.write_fluent_input_from_table(X,R,'sphere_slice_file',['temperature','velocity'])

#read output from fluent

with SphereSliceFile(os.path.join(data_folder,'sphere.ssf.out')) as nssf:
    df = nssf.readdf()
    print(df)
# Out:
#             x-coordinate  y-coordinate  z-coordinate  temperature
# cellnumber
# 1              -0.000039      0.007970      0.065993   352.458173
# 2              -0.000118      0.007965      0.065988   352.493354
# 3              -0.000039      0.007970      0.065660   353.805610
# 4              -0.000196      0.007957      0.065981   352.569221
# 5              -0.000118      0.007965      0.065691   353.842215
# ...                  ...           ...           ...          ...
# 36             -0.000313     -0.007831      0.174045   350.187508
# 37             -0.000321     -0.007899      0.174039   350.691222
# 38             -0.000236     -0.007731      0.174046   350.223995
# 39             -0.000261     -0.007799      0.174035   350.741863
# 40             -0.000183     -0.007715      0.174037   350.733066
#
# [824 rows x 4 columns]

# %%
#read output from fluent
from fluentpy.io.classes import SphereSliceFile

with SphereSliceFile(os.path.join(data_folder,'sphere.ssf.out')) as nssf:
    df = nssf.readdf()
    print(df.shape)
    df = nssf.get_sphere_surface_data(np.mean)
    print(df)
# Out:
# (824, 4)
#     y-coordinate  z-coordinate  temperature
# 0      -0.000187     -0.000187   347.588209
# 1      -0.000176     -0.000176   468.205012
# 2      -0.000122     -0.000122   333.660848
# 3      -0.000121     -0.000121   441.438598
# 4      -0.000123     -0.000123   328.415587
# 5      -0.000123     -0.000123   413.743855
# 6      -0.000187     -0.000187   327.376457
# 7      -0.000188     -0.000188   390.075094
# 8      -0.000187     -0.000187   324.044867
# 9      -0.000189     -0.000189   383.076113
# 10     -0.000187     -0.000187   319.934659
# 11     -0.000188     -0.000188   374.363584
# 12     -0.000123     -0.000123   317.911928
# 13     -0.000125     -0.000125   364.452954
# 14     -0.000117     -0.000117   312.499126
# 15     -0.000117     -0.000117   356.311973
# 16     -0.000187     -0.000187   309.018169
# 17     -0.000182     -0.000182   348.888066
